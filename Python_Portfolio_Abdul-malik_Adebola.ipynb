# %%
## Numerical and tables

import numpy as np
import pandas as pd

## data visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fraudtest_df = pd.read_csv("fraud test.csv")

# %%
## Check the Data types of all columns imported

fraudtest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  float64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
## Confirm the Top values of the CSV data imported.

fraudtest_df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0      21/06/2020 12:14  2.291160e+15
# 1           1      21/06/2020 12:14  3.573030e+15
# 2           2      21/06/2020 12:14  3.598220e+15
# 3           3      21/06/2020 12:15  3.591920e+15
# 4           4      21/06/2020 12:15  3.526830e+15
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# 1  Williams      F             3638 Marsh Union  ...  40.3207 -110.4360
# ...

# %%
## Check the statistical analysis of the data per column

fraudtest_df.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800430e+14       9.630000   26292.000000
# 50%    277859.000000  3.521420e+15      47.290000   48174.000000
# 75%    416788.500000  4.635330e+15      83.010000   72011.000000
# max    555718.000000  4.992350e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %%
## Check for Blank Cells on all the columns

fraudtest_df.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
## Set a dataframe for Fraud and Legitimate data.

fraud_df = fraudtest_df[fraudtest_df['is_fraud'] == 1]
legit_df = fraudtest_df[fraudtest_df['is_fraud'] == 0]

# %%
# Get the number of fraudulent and legitimate transactions

fraudtest_df = pd.DataFrame(fraudtest_df)

fraudulent = fraud_df.shape[0]

legitimate = legit_df.shape[0]

print("Number of fraudulent: ", fraudulent) 
print("Number of Legitimate: ", legitimate)
# Out:
# Number of fraudulent:  2145
# Number of Legitimate:  553574

# %%
# chart to represent fraudulent and legitimate transactions

labels = ['fraudulent', 'legitimate']
sizes = [fraudulent, legitimate]
colors = ['#ff9999','#66b3ff']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Fraudulent vs. Legitimate Transactions')
plt.show()

print(f"Number of Fraudulent Transactions: {fraudulent}")
print(f"Number of Legitimate Transactions: {legitimate}")
# Out:
# Number of Fraudulent Transactions: 2145
# Number of Legitimate Transactions: 553574

# %%
#  Merchants involved in fraudulent transactions?

fraudulent_merchants = fraud_df['merchant'].value_counts().head(10)

fraudulent_merchants
# Out:
# merchant
# fraud_Romaguera, Cruickshank and Greenholt    18
# fraud_Lemke-Gutmann                           18
# fraud_Mosciski, Ziemann and Farrell           18
# fraud_Schultz, Simonis and Little             17
# fraud_Heathcote, Yost and Kertzmann           17
# fraud_Boyer PLC                               15
# fraud_Medhurst PLC                            15
# fraud_Miller-Hauck                            15
# fraud_Heathcote LLC                           15
# fraud_Kilback LLC                             15
# Name: count, dtype: int64

# %%
# Gender among customers involved mostly in fraudulent activities?

fruad_gender = fraud_df['gender'].value_counts()
legit_gender = legit_df['gender'].value_counts()

print("Gender involved in fruad are: ", fruad_gender)
print("Gender legitimate are: ",legit_gender)
# Out:
# Gender involved in fruad are:  gender
# F    1164
# M     981
# Name: count, dtype: int64
# Gender legitimate are:  gender
# F    303722
# M    249852
# Name: count, dtype: int64

# %%
# Professions of customers involved with fraudulent transactions?

fraudulent_professionals = fraud_df['job'].value_counts()

print(fraudulent_professionals)
# Out:
# job
# Science writer                 30
# Licensed conveyancer           29
# Systems developer              29
# Engineer, biomedical           28
# Colour technologist            27
#                                ..
# Video editor                    4
# Public relations officer        3
# Clinical research associate     3
# Commercial horticulturist       3
# Pilot, airline                  2
# Name: count, Length: 177, dtype: int64

# %%
# Professions of customers not involved with fraudulent transactions?

legit_professionals = legit_df['job'].value_counts()

print(legit_professionals)
# Out:
# job
# Film/video editor               4111
# Exhibition designer             3968
# Surveyor, land/geomatics        3756
# Naval architect                 3737
# Designer, ceramics/pottery      3452
#                                 ...
# Merchandiser, retail             195
# Estate manager/land agent        195
# Surveyor, hydrographic           194
# Engineer, civil (consulting)     194
# Conservator, furniture           192
# Name: count, Length: 475, dtype: int64

# %%
# fraudulent_transactions_by_city

fraud_city = fraud_df['state'].value_counts()

print(fraud_city)
# Out:
# state
# NY    175
# PA    114
# TX    113
# CA     76
# IL     76
# VA     75
# IN     75
# MN     73
# MO     71
# IA     69
# KY     67
# WI     65
# AL     63
# MI     61
# GA     58
# OK     57
# MS     54
# FL     53
# OR     48
# NC     46
# MD     46
# NJ     43
# SC     43
# CT     40
# NM     39
# OH     39
# MT     37
# KS     37
# NE     36
# AR     34
# WA     30
# AZ     27
# ND     27
# LA     22
# ID     22
# NH     20
# TN     19
# MA     18
# SD     18
# ME     15
# AK     14
# DC     10
# WY      9
# HI      9
# CO      2
# Name: count, dtype: int64

# %%
## fraudulent_transactions_by_gender

fraud_category_gender = fraud_df.groupby(['category', 'gender']).size()

print(fraud_category_gender)
# Out:
# category        gender
# entertainment   F          40
#                 M          19
# food_dining     F          46
#                 M           8
# gas_transport   F          65
#                 M          89
# grocery_net     F          19
#                 M          22
# grocery_pos     F         241
#                 M         244
# health_fitness  F          45
#                 M           7
# home            F          59
#                 M           8
# kids_pets       F          55
#                 M          10
# misc_net        F         115
#                 M         152
# misc_pos        F          54
#                 M          18
# personal_care   F          54
#                 M          16
# shopping_net    F         234
#                 M         272
# shopping_pos    F         106
#                 M         107
# travel          F          31
#                 M           9
# dtype: int64

# %%
# Specific transaction amounts that are more likely to be fraudulent?

# Plot the distribution of transaction amounts for fraudulent transactions
plt.figure(figsize=(12, 6))

# Plot for fraudulent transactions
sns.histplot(fraud_df['amt'], kde=True, color='r', label='Fraudulent Transactions')

plt.title('Distribution of Transaction Amounts for Fraudulent Transactions')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
